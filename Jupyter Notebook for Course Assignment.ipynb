# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Lucille Tomin** <br> Data Engineer

# %% [markdown]
# *I am interested in data science because of the abundance of new data being generated everyday that can provide valuable insights in business, academia and othere fields. I think data science is and will continue to be one of the most valuable fields in STEM.*

# %% [markdown]
# ### The Code below is performing a simple math equation

# %%
12*36
# Out:
# 432

# %% [markdown]
# ---
# |Color|Fruit|Animal|Tea|
# |-----|-----|------|---|
# |Red|Apple|Fruit Fly|Chai|
# |Cream|Peach|Axolotl|Vanilla|
# |Green|Avocado|Lizard|Sencha|
# ~~3 items in this section: horizontal line, table, strikethrough~~
